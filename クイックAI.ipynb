# %% [markdown]
# <a href="https://colab.research.google.com/github/dhag/colab_demo/blob/main/%E3%82%AF%E3%82%A4%E3%83%83%E3%82%AFAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import ai
response = ai.generate_text("こんにちは。What is the capital of France?")

print (response)
# Out:
# フランスの首都は**パリ**です。
